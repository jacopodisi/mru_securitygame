# %%
# %matplotlib inline
import iomanager as io
import computevalue as cv
import notebook_utils as nu
import matplotlib.pyplot as plt
from scipy.interpolate import spline
import numpy as np

# %% [markdown]
# # Value graph

# %%
result = io.load_results("results_graph_n30_d0.15vps_dom")
nu.plot_values(result[0])

# %% [markdown]
# # Scalability

# %%
times = io.load_results("statistics_n10_20_d0.25_0.25_t5")

# %%
dic = {n[0]: times[n[0], n[1]] for n in times.keys()}
nu.plot_values(dic)
